# %%
#  Synthetic control package requires scipy 1.4.1 
import scipy
print(scipy.__version__)

# !pip install scipy==1.4.1
# You may need to restart the kernel to use updated packages.
# Out:
# 1.7.3
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-macosx_10_6_intel.whl (28.4 MB)
#      |████████████████████████████████| 28.4 MB 819 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from scipy==1.4.1) (1.21.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# magenta 2.1.3 requires numba<0.50, but you have numba 0.55.1 which is incompatible.
# gym 0.18.0 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# gym 0.18.0 requires Pillow<=7.2.0, but you have pillow 9.0.1 which is incompatible.
# Successfully installed scipy-1.4.1

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.4.1

# %%
# Install synthetic control package 
# !pip install SyntheticControlMethods
# Out:
# Requirement already satisfied: SyntheticControlMethods in /Users/davidfix/anaconda3/lib/python3.7/site-packages (1.1.17)
# Requirement already satisfied: pandas>=1.1.2 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (1.3.5)
# Requirement already satisfied: cvxpy>=1.1.7 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (1.2.1)
# Requirement already satisfied: jinja2>=2.10 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (3.0.3)
# Requirement already satisfied: numpy>=1.17 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (1.21.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (1.4.1)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from SyntheticControlMethods) (3.5.1)
# Requirement already satisfied: ecos>=2 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from cvxpy>=1.1.7->SyntheticControlMethods) (2.0.10)
# Requirement already satisfied: osqp>=0.4.1 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from cvxpy>=1.1.7->SyntheticControlMethods) (0.6.2.post5)
# Requirement already satisfied: scs>=1.1.6 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from cvxpy>=1.1.7->SyntheticControlMethods) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from jinja2>=2.10->SyntheticControlMethods) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.2.3->SyntheticControlMethods) (2.8.2)
# Requirement already satisfied: qdldl in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from osqp>=0.4.1->cvxpy>=1.1.7->SyntheticControlMethods) (0.1.5.post2)
# Requirement already satisfied: pytz>=2017.3 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.2->SyntheticControlMethods) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/davidfix/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->SyntheticControlMethods) (1.16.0)

# %%
# Imports packages 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn import linear_model
from matplotlib import pyplot as plt
import os
from SyntheticControlMethods import Synth, DiffSynth

# %matplotlib inline

# %%
# Import dataframes for both the 5 and 10 feature datasets 
path = os.getcwd()

data_5 = pd.read_csv(path+'/1_CSV_Data/Cell_Phone_DF5.csv')
data_10 = pd.read_csv(path+'/1_CSV_Data/Cell_Phone_DF10.csv')

# %%
# Split out year and turn into int as column is currently a string e.g. 2015-2016
data_5['first_year'] = data_5.schoolyear.apply(lambda x: x[:4])
data_5["first_year"] = data_5["first_year"].astype(str).astype(int)

data_10['first_year'] = data_10.schoolyear.apply(lambda x: x[:4])
data_10["first_year"] = data_10["first_year"].astype(str).astype(int)


#rename columns to make them easier to understand 
data_5.rename(columns = {'first_year':'year', 'Estimate Total Living in household with Supplemental Security Income (SSI), cash public assistance income, or Food Stamps/SNAP in the past 12 months':'gov_aid', 'fundbalanceas%ofexpenditure':'balance_of_expenditure', 'Estimate Median household income in the past 12 months (in 2018 inflation-adjusted dollars)':'median_income'}, inplace = True)
data_10.rename(columns = {'first_year':'year', 'Estimate Total Living in household with Supplemental Security Income (SSI), cash public assistance income, or Food Stamps/SNAP in the past 12 months':'gov_aid', 'fundbalanceas%ofexpenditure':'balance_of_expenditure', 'Estimate Median household income in the past 12 months (in 2018 inflation-adjusted dollars)':'median_income',"Estimate Total Bachelor's degree": "Bachelor degree", "Estimate Total Master's degree" : "Master degree" }, inplace = True)

# %%
# Drop columns that will not be used in the model 
data_5.drop(['Unnamed: 0', 'schoolyear','districtcode'] ,axis=1, inplace=True)
data_10.drop(['Unnamed: 0', 'schoolyear','districtcode','english_language_learners_enrollment.1'] ,axis=1, inplace=True)

# %%
# Check years 
data_5['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2020])

# %%
# Build synthetic control models based off of the two DFs. Variables in model inlcude Dependent 8th_math_percentmet, Identifiers to split between control and treatment 1) districtname and 2) year  
sc_5 = Synth(data_5, "8th_math_percentmet", "districtname", "year", 2019, 'Forest Hills Public Schools', n_optim=10, pen="auto", random_seed=0)

sc_10 = Synth(data_10, "8th_math_percentmet", "districtname", "year", 2019, 'Forest Hills Public Schools', n_optim=10, pen="auto", random_seed=0)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  8.98230D+03    |proj g|=  2.00000D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      2      5      8     0     2   9.095D-05   2.174D+02
#   F =   217.43555555608344
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.07293D+04    |proj g|=  3.48944D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      1      2      7     0     7   0.000D+00   8.429D+03
#   F =   8429.4022222237327
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.56241D+03    |proj g|=  1.63990D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      2      3      8     0     2   1.222D-04   2.174D+02
#   F =   217.43555555608137
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.37763D+04    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00   1.378D+04
#   F =   13776.322222222227
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.42940D+03    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00   8.429D+03
#   F =   8429.4022222222247
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.56043D+02    |proj g|=  1.76693D+01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      2     19      8     0     4   2.245D-04   2.174D+02
#   F =   217.43555555608083
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.48780D+04    |proj g|=  9.78951D+00
# /Users/davidfix/anaconda3/lib/python3.7/site-packages/cvxpy/problems/problem.py:1338: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "
# At iterate    3    f=  7.13822D+03    |proj g|=  1.51066D+01
#
# At iterate    6    f=  7.02455D+03    |proj g|=  1.51066D+01
#
# At iterate    9    f=  6.96628D+03    |proj g|=  4.89337D+00
#  Nonpositive definiteness in Cholesky factorization in formt;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     11     92     23     0     7   1.511D+01   6.966D+03
#   F =   6966.2436444495233
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.17193D+04    |proj g|=  6.40693D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      1      3      7     0     7   6.407D+00   1.172D+04
#   F =   11719.336109181144
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.02462D+03    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00   9.025D+03
#   F =   9024.6188888888901
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00280D+02    |proj g|=  1.56319D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      1      6      1     0     0   1.563D-05   1.003D+02
#   F =   100.28048888889018
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  4.23597D+03    |proj g|=  2.00000D+01
#
# At iterate    3    f=  6.49496D+02    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      3      4     13     0     7   0.000D+00   6.495D+02
#   F =   649.49555555555366
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.10831D+03    |proj g|=  1.75970D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      1      2     11     0    11   0.000D+00   1.003D+02
#   F =   100.28048888889481
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.28503D+03    |proj g|=  2.42525D+00
#
# At iterate    3    f=  1.08643D+03    |proj g|=  1.97240D+01
#
# At iterate    6    f=  1.25654D+02    |proj g|=  1.88234D+01
#
# At iterate    9    f=  9.50549D+01    |proj g|=  1.85894D+01
#   ys=-3.558E-02  -gs= 2.489E+00 BFGS update SKIPPED
#   Positive dir derivative in projection
#   Using the backtracking step
#   ys=-5.641E+02  -gs= 1.904E+01 BFGS update SKIPPED
#  Nonpositive definiteness in Cholesky factorization in formk;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   12    f=  3.69109D+01    |proj g|=  1.76678D+01
#   ys=-2.300E-05  -gs= 1.338E-02 BFGS update SKIPPED
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# At iterate   15    f=  3.68969D+01    |proj g|=  1.76677D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11     15     89     44     3     3   1.767D+01   3.690D+01
#   F =   36.896866521229455
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.23561D+02    |proj g|=  5.55478D+00
#   ys=-4.919E-02  -gs= 1.053E+02 BFGS update SKIPPED
#
# At iterate    3    f=  8.17474D+02    |proj g|=  5.34118D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      4     79     32     1     9   5.341D+00   8.175D+02
#   F =   817.47407372615191
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.96042D+03    |proj g|=  1.67258D+01
#
# At iterate    3    f=  2.61478D+03    |proj g|=  1.81899D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      3      5     13     0     6   1.819D-04   2.615D+03
#   F =   2614.7805555555551
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.24936D+03    |proj g|=  1.31114D+01
#
# At iterate    3    f=  2.33129D+02    |proj g|=  1.59433D+01
#
# At iterate    6    f=  1.62520D+01    |proj g|=  8.98682D+00
#
# At iterate    9    f=  7.94570D+00    |proj g|=  5.65047D+00
#
# At iterate   12    f=  6.92257D+00    |proj g|=  1.22484D+00
#
# At iterate   15    f=  2.94099D+00    |proj g|=  9.81378D-01
#
# At iterate   18    f=  2.93818D+00    |proj g|=  9.84111D-01
#
# At iterate   21    f=  2.93249D+00    |proj g|=  1.62195D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11     22     61     34     0     2   4.667D-05   2.932D+00
#   F =   2.9324886529353158
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.07117D+02    |proj g|=  1.55186D+01
#
# At iterate    3    f=  3.11827D+02    |proj g|=  1.88263D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      3      7     19     0    11   1.883D+01   3.118D+02
#   F =   311.82695742623912
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.65651D+03    |proj g|=  1.52930D+01
#
# At iterate    3    f=  1.80887D+03    |proj g|=  1.97305D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      5     15     15     0     4   0.000D+00   6.495D+02
#   F =   649.49555555555503
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         1 variables are exactly at the bounds
#  The initial X is infeasible.  Restart with its projection.
# At iterate    0    f=  2.60766D+01    |proj g|=  9.99065D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      1     12      6     0     6   0.000D+00   2.560D+01
#   F =   25.600555555555822
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.59241D+03    |proj g|=  1.25911D+01
#
# At iterate    3    f=  6.38064D+02    |proj g|=  2.00000D+01
#   ys=-5.697E+02  -gs= 1.971E+03 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11      5     35     17     1     3   0.000D+00   2.803D+02
#   F =   280.28722222222120
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
# Set style of graphs 
plt.style.use('fivethirtyeight')

# Plot synthetic control for 5 feature model 
sc_5.plot(["original", "pointwise", "cumulative"], treated_label="Forest Hills Public Schools", 
            synth_label="Synthetic Control", treatment_label="Cellphone Ban")

# %%
# Plot synthetic control for 10 feature model 

sc_10.plot(["original", "pointwise", "cumulative"], treated_label="Forest Hills Public Schools", 
            synth_label="Synthetic Control", treatment_label="Cellphone Ban")

# %%
# Districts identified for 5-feature model synthetic control 
sc_5.original_data.weight_df
# Out:
#                      Weight
# Saline Area Schools     1.0

# %%
# Districts identified for 10-feature model synthetic control 
sc_10.original_data.weight_df
# Out:
#                                       Weight
# Troy School District                0.939018
# West Ottawa Public School District  0.060982

# %%
# Metrics for 5-feature model synthetic control 
sc_5.original_data.rmspe_df
# Out:
#                           unit  pre_rmspe  post_rmspe  post/pre
# 0  Forest Hills Public Schools   5.007007   12.226667  2.441911

# %%
# Metrics for 10-feature model synthetic control 
sc_10.original_data.rmspe_df
# Out:
#                           unit  pre_rmspe  post_rmspe  post/pre
# 0  Forest Hills Public Schools   0.856226    2.101335  2.454184

# %%
# Breakdown of 5-feature model similarities between control and treatment group 
sc_5.original_data.comparison_df
# Out:
#                                   Forest Hills Public Schools  \
# 8th_math_percentmet                                     66.93
# attendance                                              96.07
# teacher_min_effective_percentage                         0.61
# median_income                                       104785.00
# balance_of_expenditure                                  14.24
# gov_aid                                                398.00
#
#                                   Synthetic Forest Hills Public Schools  \
# 8th_math_percentmet                                               63.37
# attendance                                                        95.90
# teacher_min_effective_percentage                                   0.79
# median_income                                                 110321.00
# balance_of_expenditure                                             5.20
# gov_aid                                                          684.00
#
#                                     WMAPE  Importance
# 8th_math_percentmet                  3.56        0.29
# attendance                           0.17        0.08
# teacher_min_effective_percentage     0.18        0.00
# median_income                     5536.00        0.29
# balance_of_expenditure               9.04        0.03
# gov_aid                            286.00        0.30

# %%
# Breakdown of 10-feature model similarities between control and treatment group 
sc_10.original_data.comparison_df
# Out:
#                                       Forest Hills Public Schools  \
# 8th_math_percentmet                                         66.93
# english_language_learners_enrollment                       424.50
# attendance                                                  96.07
# admin_min_effective_percentage                               0.00
# teacher_min_effective_percentage                             0.61
# median_income                                           104785.00
# Bachelor degree                                          12545.00
# Master degree                                             6055.00
# balance_of_expenditure                                      14.24
# gov_aid                                                    398.00
#
#                                       Synthetic Forest Hills Public Schools  \
# 8th_math_percentmet                                                   66.86
# english_language_learners_enrollment                                2072.95
# attendance                                                            96.54
# admin_min_effective_percentage                                         0.67
# teacher_min_effective_percentage                                       0.19
# median_income                                                      99482.23
# Bachelor degree                                                    13996.23
# Master degree                                                       9812.76
# balance_of_expenditure                                                16.74
# gov_aid                                                              893.24
#
#                                         WMAPE  Importance
# 8th_math_percentmet                      3.71        0.01
# english_language_learners_enrollment  1648.45        0.36
# attendance                               0.64        0.00
# admin_min_effective_percentage           0.67        0.06
# teacher_min_effective_percentage         0.51        0.00
# median_income                         5302.77        0.01
# Bachelor degree                       2192.16        0.20
# Master degree                         4139.38        0.36
# balance_of_expenditure                   2.49        0.00
# gov_aid                                495.24        0.00

# %%
# In-time placebo set at 2017 (1 year prior to actual treatment). 
# Placebo helps verify actual synthetic control is not a fluke 
sc_5.in_time_placebo(2017, n_optim=50)

# Visualize
sc_5.plot(['in-time placebo'], 
            treated_label="Forest Hills Public Schools",
            synth_label="Synthetic Control")
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=     Infinity    |proj g|=          NaN
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      1     21      1     0     0         NaN    Infinity
#   F =                  Infinity
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate    0    f=  9.70664D-02    |proj g|=  9.90829D-01
#   ys=-4.613E-07  -gs= 8.312E-05 BFGS update SKIPPED
#
# At iterate    3    f=  9.68709D-02    |proj g|=  9.90782D-01
#   ys=-5.327E-09  -gs= 1.375E-06 BFGS update SKIPPED
#   ys=-2.869E-04  -gs= 1.548E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      5     44      8     3     1   9.908D-01   9.687D-02
#   F =   9.6870754258831571E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.05708D-02    |proj g|=  1.81209D-01
#
# At iterate    3    f=  3.75016D-02    |proj g|=  8.07439D-03
#   ys=-7.505E-03  -gs= 3.755E-03 BFGS update SKIPPED
#   ys=-4.309E+02  -gs= 8.775E-04 BFGS update SKIPPED
#
# At iterate    6    f=  2.71106D-02    |proj g|=  9.56536D-01
#   ys=-1.665E-04  -gs= 5.511E-04 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      8     75     14     3     0   9.565D-01   2.711D-02
#   F =   2.7110466095329772E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.52634D-01    |proj g|=  6.35155D-01
#
# At iterate    3    f=  4.32353D-02    |proj g|=  2.16117D-01
#
# At iterate    6    f=  4.32318D-02    |proj g|=  3.48735D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      7     54     14     0     5   3.487D-01   4.323D-02
#   F =   4.3231838751761426E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=     Infinity    |proj g|=          NaN
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      1     21      1     0     0         NaN    Infinity
#   F =                  Infinity
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate    0    f=  1.19621D+00    |proj g|=  9.86830D-01
#   ys=-4.353E+04  -gs= 3.976E+01 BFGS update SKIPPED
#
# At iterate    3    f=  5.39079D-02    |proj g|=  1.00000D+00
#
# At iterate    6    f=  4.00805D-03    |proj g|=  9.99703D-01
#   ys=-1.183E+00  -gs= 1.127E-01 BFGS update SKIPPED
#
# At iterate    9    f=  3.69630D-03    |proj g|=  9.99387D-01
#   ys=-3.307E-08  -gs= 1.501E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     10     63     17     3     0   9.997D-01   5.251D-02
#   F =   5.2506270703424326E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=     Infinity    |proj g|=          NaN
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      1     21      1     0     0         NaN    Infinity
#   F =                  Infinity
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate    0    f=  1.01948D+00    |proj g|=  9.81872D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      2      6      6     0     0   1.148D-01   8.828D-02
#   F =   8.8283151356220127E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.90970D-02    |proj g|=  3.69123D-01
#
# At iterate    3    f=  4.32416D-02    |proj g|=  9.80136D-01
#   ys=-8.429E-01  -gs= 1.664E-04 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      5     24      9     1     0   9.948D-01   4.270D-02
#   F =   4.2697714701804876E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.18331D-01    |proj g|=  9.36371D-01
#
# At iterate    3    f=  4.70355D-02    |proj g|=  2.86523D-02
#   ys=-7.825E-04  -gs= 1.881E-04 BFGS update SKIPPED
#
# At iterate    6    f=  3.58731D-02    |proj g|=  3.27587D-02
#   ys=-2.748E-06  -gs= 3.777E-05 BFGS update SKIPPED
#   ys=-4.610E-11  -gs= 5.364E-09 BFGS update SKIPPED
#
# At iterate    9    f=  3.58719D-02    |proj g|=  3.18583D-02
#   ys=-2.488E-10  -gs= 3.614E-08 BFGS update SKIPPED
#   ys=-3.913E-10  -gs= 9.305E-08 BFGS update SKIPPED
#
# At iterate   12    f=  3.58717D-02    |proj g|=  3.26166D-02

# %%
# In-time placebo set at 2017 (1 year prior to actual treatment). 
# Placebo helps verify actual synthetic control is not a fluke 

sc_10.in_time_placebo(2017, n_optim=50)

#Visualize
sc_10.plot(['in-time placebo'], 
            treated_label="Forest Hills Public Schools",
            synth_label="Synthetic Control")
# Out:
# /usr/local/lib/python3.7/dist-packages/cvxpy/problems/problem.py:1338: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "
# /usr/local/lib/python3.7/dist-packages/SyntheticControlMethods/plot.py:255: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(n_panels, 1, idx)

# %%
# Visualize treatment and control shools average math schools over the years 
ax = plt.subplot(1, 1, 1)
data_5['Forest_Hill'] = data_5['districtname'] =='Forest Hills Public Schools'
(data_5.assign(forest = np.where(data_5["Forest_Hill"], "Forest Hill Public", "Other District"))
 .groupby(["year", "Forest_Hill"])
 ["8th_math_percentmet"]
 .mean()
 .reset_index()
 .pivot("year", "Forest_Hill", "8th_math_percentmet")
 .plot(ax=ax, label='Roll', figsize=(10,5)))

plt.vlines(x=2018, ymin=40, ymax=100, linestyle=":", lw=2, label="Cell Phone Ban")
plt.xlabel("year")
plt.ylabel("Math Scores")
plt.title("Mean Math Scores for Treatment and Control")
plt.legend();
